# %%
from TuneInsight import TuneInsight
ti = TuneInsight()
# Out:
# Authentication successful.
# 127.0.0.1 - - [24/Mar/2024 12:32:53] "GET /callback?code=AQAnoXlrzRjl7pymJTT7bfc5ir-J45O_ZRgf04HrFw-IKTh5JnRNwfeBs7RcAHUerd_pDv3APdelUnyFSaS6zBq7LxTUZIfkV8r3T25vDbIM9sk8hX2XoQLgvfj4bQEI_FdYFANewvWGqir7clAi0pY-e-PkWvIeh-bhozcoxMcaasTMcBg-9FAzxpQLM4HRkd8nq6ejQLOeHF3IKEQMFeaaCs--vE9BlDzszZJYI_hJpG0gH3-nFLDvU-y2ub63sJCgk96aKcZ2exx7fgvyzK4TpLqLlcJxlrFxz9G-GzUgTobPmbmKu_vHMoNr4Nc-WA2oILs9Nqj_xqFHBhA HTTP/1.1" 200 -

# %%
playlist_df = ti.get_user_playlists(to_csv=True)
playlist_df.head()
# Out:
#               songs         playlist                  genre  \
# 0  Ajj Din Chadheya   My Playlist #4  classic pakistani pop
# 1         Minecraft  minecraft music                  pixel
# 2       Moog City 2  minecraft music                  pixel
# 3          Mutation  minecraft music                  pixel
# 4       Living Mice  minecraft music                  pixel
#
#                  artist                                              album  \
# 0  Rahat Fateh Ali Khan  Love Aaj Kal (Original Motion Picture Soundtrack)
# 1                  C418                           Minecraft - Volume Alpha
# 2                  C418                            Minecraft - Volume Beta
# 3                  C418                            Minecraft - Volume Beta
# 4                  C418                           Minecraft - Volume Alpha
#
#   release_date  is_local  explicit  popularity  duration_min  ...  energy  \
# 0   2009-07-31     False     False          69      5.250217  ...  0.7010
# 1   2011-03-04     False     False          69      4.233333  ...  0.0154
# 2   2013-11-09     False     False          66      3.000000  ...  0.0771
# 3   2013-11-09     False     False          61      3.083333  ...  0.0265
# 4   2011-03-04     False     False          64      2.958333  ...  0.0573
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0  9.0    -4.540   1.0       0.0823         0.536          0.000008    0.1180
# 1  1.0   -22.923   1.0       0.0426         0.980          0.636000    0.0662
# 2  4.0   -24.893   0.0       0.0383         0.931          0.947000    0.1010
# 3  1.0   -20.832   1.0       0.0420         0.978          0.963000    0.0817
# 4  7.0   -22.465   1.0       0.0403         0.883          0.609000    0.0484
#
#    valence    tempo
# 0   0.8180  171.856
# 1   0.1160   83.680
# 2   0.2320  141.715
# 3   0.0391   73.097
# 4   0.0395   74.970
#
# [5 rows x 21 columns]

# %%
saved_episodes = ti.get_user_episodes(to_csv = True)
saved_episodes.head()
# Out:
#                                                 name  duration_min language  \
# 0  ZakirKhan On Parents, Relationship, Bollywood,...     81.823333    en-US
# 1  Ep# 13 | WTF does it take to Build Influence T...    189.248000       en
# 2  Ep #11 | WTF Goes into Building a Fashion, Bea...    203.990033       en
# 3  The Growing Wealth And Power of Gautam Adani d...     98.325333    en-US
# 4  Declining Indian Export & Reality Of Indian Ed...     74.351333    en-US
#
#   release_date                           show      publisher  explicit
# 0   2023-12-13  Figuring Out with Raj Shamani    Raj Shamani     False
# 1   2023-11-20      WTF is with Nikhil Kamath  Nikhil Kamath      True
# 2   2023-10-07      WTF is with Nikhil Kamath  Nikhil Kamath      True
# 3   2023-01-25  Figuring Out with Raj Shamani    Raj Shamani     False
# 4   2023-06-07  Figuring Out with Raj Shamani    Raj Shamani     False

# %%
top_tracks = ti.get_top_tracks(to_csv=True,scale=True)
top_tracks.head()
# Out:
#                                   songs              genre         artist  \
# 0                   No Wind At The Dock        lo-fi beats  Jaideep Sahni
# 1                                Heaven         chillsynth  Jaideep Sahni
# 2  Tera Mujhse - From "Aa Gale Lag Jaa"  classic bollywood  Jaideep Sahni
# 3                           Dontyouknow        lo-fi beats  Jaideep Sahni
# 4                      Main Yahaan Hoon  classic bollywood  Jaideep Sahni
#
#                  album release_date  is_local  explicit  popularity  \
# 0            Pool Days   2022-01-07     False     False           0
# 1  1 A.M Chill Session   2023-04-10     False     False          40
# 2     Timeless Kishore   2013-01-01     False     False          40
# 3           Vondelpark   2020-04-04     False     False           0
# 4         Veer - Zaara   2004-09-18     False     False          67
#
#    duration_min  danceability    energy       key  loudness      mode  \
# 0      2.003200      1.368622 -2.493633  0.339934 -4.329336  0.728431
# 1      4.713300      0.580662  0.573307  0.636388 -0.419636 -1.372813
# 2      5.661100     -1.511735  0.674693 -1.438791  1.015816  0.728431
# 3      2.253733     -0.326485 -1.819413  0.043480 -1.105448 -1.372813
# 4      4.919283     -0.472158  1.227249 -0.252974  0.268761 -1.372813
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo
# 0     0.594033      1.308598          2.796604 -0.558257 -1.093133 -0.166628
# 1     0.360795      0.011218          3.377966 -0.550470 -0.974225  2.245987
# 2    -0.251708      0.629018         -0.354078 -0.780949 -0.232236 -1.384591
# 3     6.808304      0.999698          0.743544 -0.433674 -0.936174 -1.216438
# 4     0.044403      0.443678         -0.300467 -0.668045  0.899772  1.954755
